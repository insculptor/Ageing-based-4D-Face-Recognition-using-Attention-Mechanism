# %% [markdown]
# <a id="5.1"></a>
# ### 5.1 Training 3DVAEGAN

# %% [markdown]
# Results obtained while training the model on complete dataset with 32 binvox cube

# %%
train_vae(args)
# Out:
# model=3DVAEGAN_cube=32_bs=64_g_lr=0.0025_d_lr=0.001_z=norm_bias=False_sl=True
# Dataset/Bosphorous/PreProcessed/
# using cuda
# 2108 Checkpoint/3DVAEGAN/Pickle
# VAEGAN Training:   0%|                                                                        | 0/3000 [00:00<?, ?it/s]
# 0it [00:00, ?it/s]
# 1it [00:05,  5.09s/it]
# 2it [00:09,  4.90s/it]
# 3it [00:13,  4.76s/it]
# 4it [00:18,  4.68s/it]
# 5it [00:22,  4.58s/it]
# 6it [00:27,  4.58s/it]
# 7it [00:31,  4.51s/it]
# 8it [00:36,  4.59s/it]
# 9it [00:40,  4.51s/it]
# 10it [00:45,  4.46s/it]
# 11it [00:49,  4.41s/it]
# 12it [00:53,  4.38s/it]
# 13it [00:58,  4.43s/it]
# 14it [01:02,  4.47s/it]
# 15it [01:07,  4.57s/it]
# 16it [01:12,  4.56s/it]
# 17it [01:16,  4.50s/it]
# 18it [01:21,  4.48s/it]
# 19it [01:25,  4.49s/it]
# 20it [01:30,  4.50s/it]
# 21it [01:34,  4.48s/it]
# 22it [01:39,  4.49s/it]
# 23it [01:43,  4.57s/it]
# 24it [01:48,  4.53s/it]
# 25it [01:52,  4.55s/it]
# 26it [01:57,  4.51s/it]
# 27it [02:01,  4.54s/it]
# ...
